# %%
import pandas as pd

# %%
data_ox = pd.read_csv('https://raw.githubusercontent.com/OxCGRT/covid-policy-tracker/master/data/OxCGRT_latest.csv', low_memory=False)
#data_ox.shape

data_ox.to_csv('C:\\Users\\sarah\\Documents\\IRONHACK\\Final_Project_Mod2\\data\\oxford_raw.csv')

# %%
#https://github.com/OxCGRT/covid-policy-tracker/blob/master/documentation/codebook.md
#I used the codebook to understand the columns and sort them

data_ox.columns
# Out:
# Index(['CountryName', 'CountryCode', 'RegionName', 'RegionCode', 'Date',
#        'C1_School closing', 'C1_Flag', 'C2_Workplace closing', 'C2_Flag',
#        'C3_Cancel public events', 'C3_Flag', 'C4_Restrictions on gatherings',
#        'C4_Flag', 'C5_Close public transport', 'C5_Flag',
#        'C6_Stay at home requirements', 'C6_Flag',
#        'C7_Restrictions on internal movement', 'C7_Flag',
#        'C8_International travel controls', 'E1_Income support', 'E1_Flag',
#        'E2_Debt/contract relief', 'E3_Fiscal measures',
#        'E4_International support', 'H1_Public information campaigns',
#        'H1_Flag', 'H2_Testing policy', 'H3_Contact tracing',
#        'H4_Emergency investment in healthcare', 'H5_Investment in vaccines',
#        'M1_Wildcard', 'ConfirmedCases', 'ConfirmedDeaths', 'StringencyIndex',
#        'StringencyIndexForDisplay', 'StringencyLegacyIndex',
#        'StringencyLegacyIndexForDisplay', 'GovernmentResponseIndex',
# ...

# %%
data_ox = data_ox[['CountryName', 'RegionName', 'Date', 'C1_School closing', 'C2_Workplace closing',
         'C3_Cancel public events', 'C4_Restrictions on gatherings', 'C5_Close public transport', 
         'C6_Stay at home requirements', 'C7_Restrictions on internal movement', 'C8_International travel controls', 
         'E1_Income support', 'E2_Debt/contract relief', 'E3_Fiscal measures', 'E4_International support', 
         'H1_Public information campaigns', 'H2_Testing policy', 'H3_Contact tracing', 
         'H4_Emergency investment in healthcare', 'H5_Investment in vaccines', 'ConfirmedCases', 'ConfirmedDeaths', 
         'StringencyIndexForDisplay', 'StringencyLegacyIndexForDisplay', 'GovernmentResponseIndexForDisplay',  
         'ContainmentHealthIndexForDisplay', 'EconomicSupportIndexForDisplay']]

# %%
data_ox.to_csv('C:\\Users\\sarah\\Documents\\IRONHACK\\Final_Project_Mod2\\data\\oxford_clean.csv')

# %%
data_ox.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59045 entries, 0 to 59044
# Data columns (total 32 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   CountryName                            59045 non-null  object
#  1   RegionName                             13720 non-null  object
#  2   Date                                   59045 non-null  int64
#  3   C1_School closing                      57202 non-null  float64
#  4   C2_Workplace closing                   57088 non-null  float64
#  5   C3_Cancel public events                57165 non-null  float64
#  6   C4_Restrictions on gatherings          57121 non-null  float64
#  7   C5_Close public transport              57290 non-null  float64
#  8   C6_Stay at home requirements           57132 non-null  float64
#  9   C7_Restrictions on internal movement   57244 non-null  float64
# ...

# %%
coronanet_all = pd.read_csv('C:\\Users\\sarah\\Documents\\IRONHACK\\Final_Project_Mod2\\coronanet_release_allvars.csv')
coronanet_all.shape
# Out:
# (31214, 39)

# %%
coronanet = pd.read_csv('C:\\Users\\sarah\\Documents\\IRONHACK\\Final_Project_Mod2\\coronanet_release.csv')
coronanet.shape
# Out:
# (31214, 39)

# %%
coronanet_all == coronanet

#These 2 tables have different entries, I'll use SQL to compare them.
# Out:
#        record_id  policy_id  entry_type  correct_type  update_type  \
# 0          False      False        True          True        False
# 1          False      False        True          True        False
# 2          False      False        True         False        False
# 3          False      False        True         False        False
# 4          False      False        True         False        False
# ...          ...        ...         ...           ...          ...
# 31209      False      False        True          True        False
# 31210      False      False        True          True        False
# 31211      False      False        True          True        False
# 31212      False      False        True          True        False
# 31213      False      False        True         False        False
#
#        update_level  description  date_announced  date_start  date_end  ...  \
# 0             False        False           False       False     False  ...
# ...

# %%
owid = pd.read_csv('C:\\Users\\sarah\\Documents\\IRONHACK\\Final_Project_Mod2\\owid-covid-data.csv')
owid
# Out:
#       iso_code continent       location        date  total_cases  new_cases  \
# 0          AFG      Asia    Afghanistan  31/12/2019          0.0        0.0
# 1          AFG      Asia    Afghanistan  01/01/2020          0.0        0.0
# 2          AFG      Asia    Afghanistan  02/01/2020          0.0        0.0
# 3          AFG      Asia    Afghanistan  03/01/2020          0.0        0.0
# 4          AFG      Asia    Afghanistan  04/01/2020          0.0        0.0
# ...        ...       ...            ...         ...          ...        ...
# 40954      NaN       NaN  International  28/08/2020        696.0        NaN
# 40955      NaN       NaN  International  29/08/2020        696.0        NaN
# 40956      NaN       NaN  International  30/08/2020        696.0        NaN
# 40957      NaN       NaN  International  31/08/2020        696.0        NaN
# 40958      NaN       NaN  International  01/09/2020        696.0        NaN
#
# ...

# %%
owid.isnull().sum()
# Out:
# iso_code                             246
# continent                            492
# location                               0
# date                                   0
# total_cases                          575
# new_cases                            757
# new_cases_smoothed                  1539
# total_deaths                         575
# new_deaths                           757
# new_deaths_smoothed                 1539
# total_cases_per_million              821
# new_cases_per_million                821
# new_cases_smoothed_per_million      1604
# total_deaths_per_million             821
# new_deaths_per_million               821
# new_deaths_smoothed_per_million     1604
# new_tests                          27847
# total_tests                        27516
# total_tests_per_thousand           27516
# new_tests_per_thousand             27847
# new_tests_smoothed                 26217
# new_tests_smoothed_per_thousand    26217
# tests_per_case                     27329
# ...
